# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# 在进行模拟时，请运行下方的代码来查看四轴飞行器的位置变化。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 下方代码输出了四轴飞行器的速度。

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 接下来，你可以绘制欧拉角 (Euler angles)（四轴飞行器围绕 $x$-，$y$- 和 $z$-轴的旋转）的图表，

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 在绘制每个欧拉角的速度（每秒的弧度）图之前。

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 最后，你可以使用下方代码来输出智能体选择的动作。

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-13.94535453   7.73544571  30.12697147   0.09763344   0.12309956
#    0.        ]
# [-7.50439455  3.67407387  5.67244182]
# [-0.05972005 -0.06521501  0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =   1.099 (best =   1.222), noise_scale = 3.25

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、悬停、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
## TODO: Train your agent here.
import sys
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import numpy as np

from agents.agent import Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])

task = Task(target_pos=target_pos)
agent = Agent(task)

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state)
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("Episode:[{}] reward:[{:.3f}]".format(i_episode, agent.total_reward))
            break
# Out:
# Episode:[1] reward:[29.092]
# Episode:[2] reward:[27.267]
# Episode:[3] reward:[29.947]
# Episode:[4] reward:[26.305]
# Episode:[5] reward:[26.482]
# Episode:[6] reward:[25.980]
# Episode:[7] reward:[28.398]
# Episode:[8] reward:[27.714]
# Episode:[9] reward:[27.966]
# Episode:[10] reward:[28.967]
# Episode:[11] reward:[25.098]
# Episode:[12] reward:[27.900]
# Episode:[13] reward:[24.686]
# Episode:[14] reward:[26.193]
# Episode:[15] reward:[26.574]
# Episode:[16] reward:[25.053]
# Episode:[17] reward:[27.097]
# Episode:[18] reward:[25.010]
# Episode:[19] reward:[27.969]
# Episode:[20] reward:[24.606]
# Episode:[21] reward:[26.065]
# Episode:[22] reward:[26.782]
# Episode:[23] reward:[23.904]
# Episode:[24] reward:[25.009]
# Episode:[25] reward:[25.073]
# Episode:[26] reward:[26.488]
# Episode:[27] reward:[27.410]
# Episode:[28] reward:[24.881]
# Episode:[29] reward:[24.664]
# Episode:[30] reward:[24.857]
# Episode:[31] reward:[26.388]
# Episode:[32] reward:[25.204]
# Episode:[33] reward:[26.034]
# Episode:[34] reward:[53.714]
# Episode:[35] reward:[24.321]
# Episode:[36] reward:[24.329]
# Episode:[37] reward:[24.354]
# Episode:[38] reward:[36.994]
# Episode:[39] reward:[24.315]
# Episode:[40] reward:[24.364]
# Episode:[41] reward:[25.289]
# Episode:[42] reward:[25.968]
# Episode:[43] reward:[26.311]
# Episode:[44] reward:[27.370]
# Episode:[45] reward:[27.646]
# Episode:[46] reward:[26.560]
# Episode:[47] reward:[24.992]
# Episode:[48] reward:[27.981]
# Episode:[49] reward:[25.251]
# Episode:[50] reward:[26.487]
# Episode:[51] reward:[24.811]
# Episode:[52] reward:[25.286]
# Episode:[53] reward:[28.081]
# Episode:[54] reward:[24.633]
# Episode:[55] reward:[25.928]
# Episode:[56] reward:[27.558]
# Episode:[57] reward:[25.856]
# Episode:[58] reward:[27.285]
# Episode:[59] reward:[26.098]
# Episode:[60] reward:[27.295]
# Episode:[61] reward:[27.137]
# Episode:[62] reward:[25.050]
# Episode:[63] reward:[26.407]
# Episode:[64] reward:[27.530]
# Episode:[65] reward:[26.278]
# Episode:[66] reward:[26.113]
# Episode:[67] reward:[28.104]
# Episode:[68] reward:[26.072]
# Episode:[69] reward:[28.410]
# Episode:[70] reward:[26.413]
# Episode:[71] reward:[27.242]
# Episode:[72] reward:[26.089]
# Episode:[73] reward:[24.421]
# Episode:[74] reward:[26.416]
# Episode:[75] reward:[27.212]
# Episode:[76] reward:[26.283]
# Episode:[77] reward:[27.175]
# Episode:[78] reward:[25.429]
# Episode:[79] reward:[27.424]
# Episode:[80] reward:[27.830]
# Episode:[81] reward:[24.786]
# Episode:[82] reward:[24.593]
# Episode:[83] reward:[25.243]
# Episode:[84] reward:[24.691]
# Episode:[85] reward:[28.113]
# Episode:[86] reward:[27.036]
# Episode:[87] reward:[26.601]
# Episode:[88] reward:[25.161]
# Episode:[89] reward:[26.111]
# Episode:[90] reward:[27.573]
# Episode:[91] reward:[24.654]
# Episode:[92] reward:[28.210]
# Episode:[93] reward:[27.640]
# Episode:[94] reward:[26.958]
# Episode:[95] reward:[25.999]
# Episode:[96] reward:[24.966]
# Episode:[97] reward:[26.991]
# Episode:[98] reward:[28.057]
# Episode:[99] reward:[27.811]
# Episode:[100] reward:[27.562]
# Episode:[101] reward:[26.230]
# Episode:[102] reward:[25.323]
# Episode:[103] reward:[26.015]
# Episode:[104] reward:[27.863]
# Episode:[105] reward:[24.471]
# Episode:[106] reward:[26.711]
# Episode:[107] reward:[24.986]
# Episode:[108] reward:[26.684]
# Episode:[109] reward:[26.466]
# Episode:[110] reward:[27.751]
# Episode:[111] reward:[27.694]
# Episode:[112] reward:[25.454]
# Episode:[113] reward:[28.465]
# Episode:[114] reward:[25.397]
# Episode:[115] reward:[25.917]
# Episode:[116] reward:[25.619]
# Episode:[117] reward:[27.550]
# Episode:[118] reward:[27.792]
# Episode:[119] reward:[28.586]
# Episode:[120] reward:[27.563]
# Episode:[121] reward:[25.229]
# Episode:[122] reward:[28.312]
# Episode:[123] reward:[27.311]
# Episode:[124] reward:[24.998]
# Episode:[125] reward:[25.329]
# Episode:[126] reward:[24.164]
# Episode:[127] reward:[27.281]
# Episode:[128] reward:[26.416]
# Episode:[129] reward:[27.627]
# Episode:[130] reward:[25.970]
# Episode:[131] reward:[27.480]
# Episode:[132] reward:[26.458]
# Episode:[133] reward:[24.808]
# Episode:[134] reward:[27.217]
# Episode:[135] reward:[24.831]
# Episode:[136] reward:[27.574]
# Episode:[137] reward:[27.376]
# Episode:[138] reward:[27.542]
# Episode:[139] reward:[26.086]
# Episode:[140] reward:[27.325]
# Episode:[141] reward:[26.275]
# Episode:[142] reward:[27.174]
# Episode:[143] reward:[26.288]
# Episode:[144] reward:[26.061]
# Episode:[145] reward:[27.563]
# Episode:[146] reward:[25.052]
# Episode:[147] reward:[27.311]
# Episode:[148] reward:[25.552]
# Episode:[149] reward:[27.434]
# Episode:[150] reward:[25.963]
# Episode:[151] reward:[25.145]
# Episode:[152] reward:[25.131]
# Episode:[153] reward:[25.321]
# Episode:[154] reward:[25.151]
# Episode:[155] reward:[25.016]
# Episode:[156] reward:[25.187]
# Episode:[157] reward:[27.701]
# Episode:[158] reward:[27.451]
# Episode:[159] reward:[24.999]
# Episode:[160] reward:[28.543]
# Episode:[161] reward:[28.003]
# Episode:[162] reward:[24.924]
# Episode:[163] reward:[27.849]
# Episode:[164] reward:[26.035]
# Episode:[165] reward:[27.801]
# Episode:[166] reward:[27.209]
# Episode:[167] reward:[28.168]
# Episode:[168] reward:[26.139]
# Episode:[169] reward:[27.868]
# Episode:[170] reward:[24.828]
# Episode:[171] reward:[25.206]
# Episode:[172] reward:[24.773]
# Episode:[173] reward:[27.972]
# Episode:[174] reward:[24.986]
# Episode:[175] reward:[26.346]
# Episode:[176] reward:[27.060]
# Episode:[177] reward:[27.598]
# Episode:[178] reward:[25.842]
# Episode:[179] reward:[24.788]
# Episode:[180] reward:[24.315]
# Episode:[181] reward:[24.329]
# Episode:[182] reward:[24.315]
# Episode:[183] reward:[24.326]
# Episode:[184] reward:[24.337]
# Episode:[185] reward:[24.329]
# Episode:[186] reward:[24.320]
# Episode:[187] reward:[24.331]
# Episode:[188] reward:[24.324]
# Episode:[189] reward:[24.323]
# Episode:[190] reward:[24.331]
# Episode:[191] reward:[24.318]
# Episode:[192] reward:[24.330]
# Episode:[193] reward:[24.322]
# Episode:[194] reward:[24.305]
# Episode:[195] reward:[24.326]
# Episode:[196] reward:[24.327]
# Episode:[197] reward:[24.320]
# Episode:[198] reward:[24.322]
# Episode:[199] reward:[24.319]
# Episode:[200] reward:[24.320]
# Episode:[201] reward:[24.329]
# Episode:[202] reward:[24.337]
# Episode:[203] reward:[24.317]
# Episode:[204] reward:[24.312]
# Episode:[205] reward:[24.328]
# Episode:[206] reward:[24.316]
# Episode:[207] reward:[24.329]
# Episode:[208] reward:[24.318]
# Episode:[209] reward:[24.322]
# Episode:[210] reward:[24.323]
# Episode:[211] reward:[24.328]
# Episode:[212] reward:[24.327]
# Episode:[213] reward:[24.322]
# Episode:[214] reward:[24.320]
# Episode:[215] reward:[24.323]
# Episode:[216] reward:[24.330]
# Episode:[217] reward:[24.322]
# Episode:[218] reward:[24.324]
# Episode:[219] reward:[24.324]
# Episode:[220] reward:[24.333]
# Episode:[221] reward:[24.341]
# Episode:[222] reward:[24.319]
# Episode:[223] reward:[24.328]
# Episode:[224] reward:[24.322]
# Episode:[225] reward:[24.324]
# Episode:[226] reward:[24.323]
# Episode:[227] reward:[24.328]
# Episode:[228] reward:[24.328]
# Episode:[229] reward:[24.321]
# Episode:[230] reward:[24.322]
# Episode:[231] reward:[24.317]
# Episode:[232] reward:[24.330]
# Episode:[233] reward:[24.307]
# Episode:[234] reward:[24.319]
# Episode:[235] reward:[24.326]
# Episode:[236] reward:[24.333]
# Episode:[237] reward:[24.321]
# Episode:[238] reward:[24.328]
# Episode:[239] reward:[24.320]
# Episode:[240] reward:[24.314]
# Episode:[241] reward:[24.332]
# Episode:[242] reward:[24.325]
# Episode:[243] reward:[24.323]
# Episode:[244] reward:[24.323]
# Episode:[245] reward:[24.314]
# Episode:[246] reward:[24.312]
# Episode:[247] reward:[24.325]
# Episode:[248] reward:[24.328]
# Episode:[249] reward:[24.319]
# Episode:[250] reward:[24.324]
# Episode:[251] reward:[24.328]
# Episode:[252] reward:[24.325]
# Episode:[253] reward:[24.324]
# Episode:[254] reward:[24.331]
# Episode:[255] reward:[24.327]
# Episode:[256] reward:[24.322]
# Episode:[257] reward:[24.329]
# Episode:[258] reward:[24.320]
# Episode:[259] reward:[24.322]
# Episode:[260] reward:[24.332]
# Episode:[261] reward:[24.319]
# Episode:[262] reward:[24.321]
# Episode:[263] reward:[24.322]
# Episode:[264] reward:[24.331]
# Episode:[265] reward:[24.333]
# Episode:[266] reward:[24.327]
# Episode:[267] reward:[24.323]
# Episode:[268] reward:[24.324]
# Episode:[269] reward:[24.314]
# Episode:[270] reward:[24.317]
# Episode:[271] reward:[24.317]
# Episode:[272] reward:[24.321]
# Episode:[273] reward:[24.315]
# Episode:[274] reward:[24.341]
# Episode:[275] reward:[24.334]
# Episode:[276] reward:[24.328]
# Episode:[277] reward:[24.320]
# Episode:[278] reward:[24.323]
# Episode:[279] reward:[24.340]
# Episode:[280] reward:[24.326]
# Episode:[281] reward:[24.333]
# Episode:[282] reward:[24.332]
# Episode:[283] reward:[24.329]
# Episode:[284] reward:[24.323]
# Episode:[285] reward:[24.325]
# Episode:[286] reward:[24.325]
# Episode:[287] reward:[24.319]
# Episode:[288] reward:[24.325]
# Episode:[289] reward:[24.323]
# Episode:[290] reward:[24.324]
# Episode:[291] reward:[24.322]
# Episode:[292] reward:[24.333]
# Episode:[293] reward:[24.345]
# Episode:[294] reward:[24.341]
# Episode:[295] reward:[24.314]
# Episode:[296] reward:[24.324]
# Episode:[297] reward:[24.329]
# Episode:[298] reward:[24.315]
# Episode:[299] reward:[24.330]
# Episode:[300] reward:[24.318]
# Episode:[301] reward:[24.332]
# Episode:[302] reward:[24.330]
# Episode:[303] reward:[24.321]
# Episode:[304] reward:[24.322]
# Episode:[305] reward:[24.317]
# Episode:[306] reward:[24.317]
# Episode:[307] reward:[24.320]
# Episode:[308] reward:[24.322]
# Episode:[309] reward:[24.329]
# Episode:[310] reward:[24.332]
# Episode:[311] reward:[24.330]
# Episode:[312] reward:[24.332]
# Episode:[313] reward:[24.326]
# Episode:[314] reward:[24.327]
# Episode:[315] reward:[24.324]
# Episode:[316] reward:[24.331]
# Episode:[317] reward:[24.320]
# Episode:[318] reward:[24.317]
# Episode:[319] reward:[24.330]
# Episode:[320] reward:[24.325]
# Episode:[321] reward:[24.317]
# Episode:[322] reward:[24.322]
# Episode:[323] reward:[24.309]
# Episode:[324] reward:[24.325]
# Episode:[325] reward:[24.322]
# Episode:[326] reward:[24.323]
# Episode:[327] reward:[24.326]
# Episode:[328] reward:[24.330]
# Episode:[329] reward:[24.326]
# Episode:[330] reward:[24.320]
# Episode:[331] reward:[24.307]
# Episode:[332] reward:[24.318]
# Episode:[333] reward:[24.330]
# Episode:[334] reward:[24.333]
# Episode:[335] reward:[24.333]
# Episode:[336] reward:[24.323]
# Episode:[337] reward:[24.319]
# Episode:[338] reward:[24.325]
# Episode:[339] reward:[24.334]
# Episode:[340] reward:[24.327]
# Episode:[341] reward:[24.317]
# Episode:[342] reward:[24.319]
# Episode:[343] reward:[24.321]
# Episode:[344] reward:[24.328]
# Episode:[345] reward:[24.326]
# Episode:[346] reward:[24.321]
# Episode:[347] reward:[24.326]
# Episode:[348] reward:[24.322]
# Episode:[349] reward:[24.325]
# Episode:[350] reward:[24.323]
# Episode:[351] reward:[24.325]
# Episode:[352] reward:[24.320]
# Episode:[353] reward:[24.321]
# Episode:[354] reward:[24.323]
# Episode:[355] reward:[22.051]
# Episode:[356] reward:[24.083]
# Episode:[357] reward:[26.303]
# Episode:[358] reward:[25.626]
# Episode:[359] reward:[25.568]
# Episode:[360] reward:[27.102]
# Episode:[361] reward:[26.614]
# Episode:[362] reward:[23.187]
# Episode:[363] reward:[23.702]
# Episode:[364] reward:[22.292]
# Episode:[365] reward:[24.430]
# Episode:[366] reward:[32.954]
# Episode:[367] reward:[23.553]
# Episode:[368] reward:[21.930]
# Episode:[369] reward:[27.728]
# Episode:[370] reward:[23.997]
# Episode:[371] reward:[23.414]
# Episode:[372] reward:[29.206]
# Episode:[373] reward:[31.617]
# Episode:[374] reward:[23.348]
# Episode:[375] reward:[26.677]
# Episode:[376] reward:[24.355]
# Episode:[377] reward:[25.929]
# Episode:[378] reward:[23.268]
# Episode:[379] reward:[24.680]
# Episode:[380] reward:[22.317]
# Episode:[381] reward:[27.197]
# Episode:[382] reward:[23.044]
# Episode:[383] reward:[22.808]
# Episode:[384] reward:[21.709]
# Episode:[385] reward:[29.448]
# Episode:[386] reward:[26.576]
# Episode:[387] reward:[31.990]
# Episode:[388] reward:[21.898]
# Episode:[389] reward:[22.092]
# Episode:[390] reward:[23.916]
# Episode:[391] reward:[25.924]
# Episode:[392] reward:[22.400]
# Episode:[393] reward:[27.718]
# Episode:[394] reward:[25.398]
# Episode:[395] reward:[21.684]
# Episode:[396] reward:[21.143]
# Episode:[397] reward:[23.834]
# Episode:[398] reward:[23.149]
# Episode:[399] reward:[23.616]
# Episode:[400] reward:[21.872]
# Episode:[401] reward:[24.432]
# Episode:[402] reward:[23.144]
# Episode:[403] reward:[23.534]
# Episode:[404] reward:[31.212]
# Episode:[405] reward:[21.577]
# Episode:[406] reward:[30.460]
# Episode:[407] reward:[24.784]
# Episode:[408] reward:[28.940]
# Episode:[409] reward:[28.845]
# Episode:[410] reward:[26.387]
# Episode:[411] reward:[30.309]
# Episode:[412] reward:[26.743]
# Episode:[413] reward:[29.693]
# Episode:[414] reward:[35.784]
# Episode:[415] reward:[26.242]
# Episode:[416] reward:[26.237]
# Episode:[417] reward:[25.320]
# Episode:[418] reward:[25.109]
# Episode:[419] reward:[26.249]
# Episode:[420] reward:[27.365]
# Episode:[421] reward:[28.083]
# Episode:[422] reward:[24.232]
# Episode:[423] reward:[28.283]
# Episode:[424] reward:[25.901]
# Episode:[425] reward:[27.341]
# Episode:[426] reward:[27.443]
# Episode:[427] reward:[27.482]
# Episode:[428] reward:[26.365]
# Episode:[429] reward:[26.478]
# Episode:[430] reward:[26.915]
# Episode:[431] reward:[26.819]
# Episode:[432] reward:[26.041]
# Episode:[433] reward:[27.266]
# Episode:[434] reward:[26.460]
# Episode:[435] reward:[26.667]
# Episode:[436] reward:[26.706]
# Episode:[437] reward:[27.013]
# Episode:[438] reward:[26.310]
# Episode:[439] reward:[26.586]
# Episode:[440] reward:[28.411]
# Episode:[441] reward:[26.711]
# Episode:[442] reward:[26.518]
# Episode:[443] reward:[25.727]
# Episode:[444] reward:[26.265]
# Episode:[445] reward:[26.346]
# Episode:[446] reward:[26.800]
# Episode:[447] reward:[26.255]
# Episode:[448] reward:[26.626]
# Episode:[449] reward:[27.042]
# Episode:[450] reward:[25.654]
# Episode:[451] reward:[27.717]
# Episode:[452] reward:[27.454]
# Episode:[453] reward:[28.890]
# Episode:[454] reward:[25.630]
# Episode:[455] reward:[26.508]
# Episode:[456] reward:[26.724]
# Episode:[457] reward:[27.907]
# Episode:[458] reward:[26.375]
# Episode:[459] reward:[26.637]
# Episode:[460] reward:[27.119]
# Episode:[461] reward:[26.538]
# Episode:[462] reward:[26.477]
# Episode:[463] reward:[26.562]
# Episode:[464] reward:[26.352]
# Episode:[465] reward:[26.385]
# Episode:[466] reward:[26.277]
# Episode:[467] reward:[25.860]
# Episode:[468] reward:[26.515]
# Episode:[469] reward:[26.862]
# Episode:[470] reward:[26.473]
# Episode:[471] reward:[26.556]
# Episode:[472] reward:[27.239]
# Episode:[473] reward:[26.576]
# Episode:[474] reward:[26.583]
# Episode:[475] reward:[26.920]
# Episode:[476] reward:[27.701]
# Episode:[477] reward:[26.450]
# Episode:[478] reward:[26.703]
# Episode:[479] reward:[27.083]
# Episode:[480] reward:[26.974]
# Episode:[481] reward:[27.605]
# Episode:[482] reward:[26.460]
# Episode:[483] reward:[26.610]
# Episode:[484] reward:[25.498]
# Episode:[485] reward:[26.552]
# Episode:[486] reward:[27.459]
# Episode:[487] reward:[26.467]
# Episode:[488] reward:[27.093]
# Episode:[489] reward:[26.574]
# Episode:[490] reward:[26.542]
# Episode:[491] reward:[25.413]
# Episode:[492] reward:[28.050]
# Episode:[493] reward:[26.523]
# Episode:[494] reward:[26.764]
# Episode:[495] reward:[26.529]
# Episode:[496] reward:[26.540]
# Episode:[497] reward:[27.484]
# Episode:[498] reward:[26.139]
# Episode:[499] reward:[26.506]
# Episode:[500] reward:[27.267]
# Episode:[501] reward:[27.669]
# Episode:[502] reward:[26.824]
# Episode:[503] reward:[26.405]
# Episode:[504] reward:[27.590]
# Episode:[505] reward:[26.455]
# Episode:[506] reward:[26.221]
# Episode:[507] reward:[26.475]
# Episode:[508] reward:[26.779]
# Episode:[509] reward:[26.592]
# Episode:[510] reward:[26.233]
# Episode:[511] reward:[26.647]
# Episode:[512] reward:[25.764]
# Episode:[513] reward:[26.697]
# Episode:[514] reward:[26.587]
# Episode:[515] reward:[26.198]
# Episode:[516] reward:[26.629]
# Episode:[517] reward:[26.838]
# Episode:[518] reward:[26.757]
# Episode:[519] reward:[26.837]
# Episode:[520] reward:[28.005]
# Episode:[521] reward:[27.501]
# Episode:[522] reward:[26.433]
# Episode:[523] reward:[26.372]
# Episode:[524] reward:[26.313]
# Episode:[525] reward:[26.622]
# Episode:[526] reward:[26.486]
# Episode:[527] reward:[26.837]
# Episode:[528] reward:[27.053]
# Episode:[529] reward:[26.443]
# Episode:[530] reward:[27.723]
# Episode:[531] reward:[26.556]
# Episode:[532] reward:[26.585]
# Episode:[533] reward:[26.486]
# Episode:[534] reward:[26.464]
# Episode:[535] reward:[26.720]
# Episode:[536] reward:[26.059]
# Episode:[537] reward:[26.744]
# Episode:[538] reward:[26.598]
# Episode:[539] reward:[26.518]
# Episode:[540] reward:[26.509]
# Episode:[541] reward:[27.245]
# Episode:[542] reward:[26.331]
# Episode:[543] reward:[26.289]
# Episode:[544] reward:[26.887]
# Episode:[545] reward:[27.314]
# Episode:[546] reward:[26.325]
# Episode:[547] reward:[26.691]
# Episode:[548] reward:[26.541]
# Episode:[549] reward:[26.392]
# Episode:[550] reward:[26.218]
# Episode:[551] reward:[26.488]
# Episode:[552] reward:[27.214]
# Episode:[553] reward:[26.747]
# Episode:[554] reward:[26.575]
# Episode:[555] reward:[26.605]
# Episode:[556] reward:[26.522]
# Episode:[557] reward:[27.490]
# Episode:[558] reward:[26.830]
# Episode:[559] reward:[26.725]
# Episode:[560] reward:[26.413]
# Episode:[561] reward:[26.073]
# Episode:[562] reward:[26.694]
# Episode:[563] reward:[26.619]
# Episode:[564] reward:[27.791]
# Episode:[565] reward:[26.547]
# Episode:[566] reward:[26.042]
# Episode:[567] reward:[26.451]
# Episode:[568] reward:[26.048]
# Episode:[569] reward:[26.586]
# Episode:[570] reward:[26.314]
# Episode:[571] reward:[27.303]
# Episode:[572] reward:[26.530]
# Episode:[573] reward:[25.309]
# Episode:[574] reward:[25.043]
# Episode:[575] reward:[26.801]
# Episode:[576] reward:[25.583]
# Episode:[577] reward:[25.824]
# Episode:[578] reward:[26.685]
# Episode:[579] reward:[27.315]
# Episode:[580] reward:[26.320]
# Episode:[581] reward:[26.220]
# Episode:[582] reward:[27.268]
# Episode:[583] reward:[26.460]
# Episode:[584] reward:[25.328]
# Episode:[585] reward:[26.591]
# Episode:[586] reward:[25.378]
# Episode:[587] reward:[26.290]
# Episode:[588] reward:[27.089]
# Episode:[589] reward:[26.192]
# Episode:[590] reward:[25.940]
# Episode:[591] reward:[24.659]
# Episode:[592] reward:[27.454]
# Episode:[593] reward:[29.201]
# Episode:[594] reward:[26.243]
# Episode:[595] reward:[26.515]
# Episode:[596] reward:[26.375]
# Episode:[597] reward:[26.855]
# Episode:[598] reward:[27.260]
# Episode:[599] reward:[26.814]
# Episode:[600] reward:[25.436]
# Episode:[601] reward:[24.916]
# Episode:[602] reward:[26.373]
# Episode:[603] reward:[27.245]
# Episode:[604] reward:[25.984]
# Episode:[605] reward:[26.606]
# Episode:[606] reward:[26.617]
# Episode:[607] reward:[26.487]
# Episode:[608] reward:[26.466]
# Episode:[609] reward:[29.165]
# Episode:[610] reward:[24.928]
# Episode:[611] reward:[28.267]
# Episode:[612] reward:[29.285]
# Episode:[613] reward:[24.996]
# Episode:[614] reward:[27.175]
# Episode:[615] reward:[24.733]
# Episode:[616] reward:[25.616]
# Episode:[617] reward:[26.493]
# Episode:[618] reward:[27.359]
# Episode:[619] reward:[25.546]
# Episode:[620] reward:[25.077]
# Episode:[621] reward:[25.696]
# Episode:[622] reward:[26.493]
# Episode:[623] reward:[27.552]
# Episode:[624] reward:[26.319]
# Episode:[625] reward:[25.912]
# Episode:[626] reward:[25.822]
# Episode:[627] reward:[25.718]
# Episode:[628] reward:[24.056]
# Episode:[629] reward:[25.910]
# Episode:[630] reward:[27.234]
# Episode:[631] reward:[26.734]
# Episode:[632] reward:[26.640]
# Episode:[633] reward:[26.481]
# Episode:[634] reward:[26.557]
# Episode:[635] reward:[26.627]
# Episode:[636] reward:[26.488]
# Episode:[637] reward:[25.193]
# Episode:[638] reward:[26.514]
# Episode:[639] reward:[26.458]
# Episode:[640] reward:[25.388]
# Episode:[641] reward:[24.980]
# Episode:[642] reward:[26.639]
# Episode:[643] reward:[26.234]
# Episode:[644] reward:[26.125]
# Episode:[645] reward:[26.755]
# Episode:[646] reward:[27.362]
# Episode:[647] reward:[26.525]
# Episode:[648] reward:[27.704]
# Episode:[649] reward:[24.845]
# Episode:[650] reward:[25.235]
# Episode:[651] reward:[26.058]
# Episode:[652] reward:[24.809]
# Episode:[653] reward:[25.746]
# Episode:[654] reward:[26.238]
# Episode:[655] reward:[26.076]
# Episode:[656] reward:[25.043]
# Episode:[657] reward:[26.772]
# Episode:[658] reward:[26.582]
# Episode:[659] reward:[26.395]
# Episode:[660] reward:[27.547]
# Episode:[661] reward:[26.059]
# Episode:[662] reward:[27.227]
# Episode:[663] reward:[24.847]
# Episode:[664] reward:[24.976]
# Episode:[665] reward:[26.458]
# Episode:[666] reward:[26.488]
# Episode:[667] reward:[26.356]
# Episode:[668] reward:[24.467]
# Episode:[669] reward:[26.435]
# Episode:[670] reward:[25.266]
# Episode:[671] reward:[26.508]
# Episode:[672] reward:[27.592]
# Episode:[673] reward:[26.477]
# Episode:[674] reward:[26.495]
# Episode:[675] reward:[26.350]
# Episode:[676] reward:[24.842]
# Episode:[677] reward:[26.039]
# Episode:[678] reward:[25.548]
# Episode:[679] reward:[26.569]
# Episode:[680] reward:[26.755]
# Episode:[681] reward:[25.181]
# Episode:[682] reward:[26.380]
# Episode:[683] reward:[26.345]
# Episode:[684] reward:[26.670]
# Episode:[685] reward:[26.463]
# Episode:[686] reward:[26.014]
# Episode:[687] reward:[24.688]
# Episode:[688] reward:[26.045]
# Episode:[689] reward:[27.282]
# Episode:[690] reward:[24.788]
# Episode:[691] reward:[29.418]
# Episode:[692] reward:[26.521]
# Episode:[693] reward:[24.815]
# Episode:[694] reward:[26.470]
# Episode:[695] reward:[26.156]
# Episode:[696] reward:[26.968]
# Episode:[697] reward:[24.764]
# Episode:[698] reward:[31.010]
# Episode:[699] reward:[27.380]
# Episode:[700] reward:[25.762]
# Episode:[701] reward:[26.400]
# Episode:[702] reward:[27.354]
# Episode:[703] reward:[26.328]
# Episode:[704] reward:[27.646]
# Episode:[705] reward:[26.878]
# Episode:[706] reward:[25.869]
# Episode:[707] reward:[27.183]
# Episode:[708] reward:[27.243]
# Episode:[709] reward:[27.200]
# Episode:[710] reward:[26.485]
# Episode:[711] reward:[26.929]
# Episode:[712] reward:[26.909]
# Episode:[713] reward:[26.515]
# Episode:[714] reward:[26.234]
# Episode:[715] reward:[27.259]
# Episode:[716] reward:[27.667]
# Episode:[717] reward:[26.640]
# Episode:[718] reward:[26.543]
# Episode:[719] reward:[26.276]
# Episode:[720] reward:[26.880]
# Episode:[721] reward:[26.679]
# Episode:[722] reward:[26.571]
# Episode:[723] reward:[26.427]
# Episode:[724] reward:[26.226]
# Episode:[725] reward:[26.172]
# Episode:[726] reward:[26.937]
# Episode:[727] reward:[27.591]
# Episode:[728] reward:[27.015]
# Episode:[729] reward:[26.556]
# Episode:[730] reward:[26.623]
# Episode:[731] reward:[26.946]
# Episode:[732] reward:[26.467]
# Episode:[733] reward:[26.180]
# Episode:[734] reward:[26.288]
# Episode:[735] reward:[26.476]
# Episode:[736] reward:[26.504]
# Episode:[737] reward:[27.015]
# Episode:[738] reward:[26.640]
# Episode:[739] reward:[26.352]
# Episode:[740] reward:[26.182]
# Episode:[741] reward:[26.500]
# Episode:[742] reward:[25.391]
# Episode:[743] reward:[25.274]
# Episode:[744] reward:[26.850]
# Episode:[745] reward:[26.612]
# Episode:[746] reward:[26.710]
# Episode:[747] reward:[26.623]
# Episode:[748] reward:[26.529]
# Episode:[749] reward:[26.892]
# Episode:[750] reward:[26.477]
# Episode:[751] reward:[27.470]
# Episode:[752] reward:[27.655]
# Episode:[753] reward:[26.468]
# Episode:[754] reward:[26.481]
# Episode:[755] reward:[26.055]
# Episode:[756] reward:[26.470]
# Episode:[757] reward:[26.666]
# Episode:[758] reward:[26.458]
# Episode:[759] reward:[26.464]
# Episode:[760] reward:[26.638]
# Episode:[761] reward:[27.480]
# Episode:[762] reward:[27.236]
# Episode:[763] reward:[26.133]
# Episode:[764] reward:[26.729]
# Episode:[765] reward:[27.744]
# Episode:[766] reward:[26.793]
# Episode:[767] reward:[25.911]
# Episode:[768] reward:[26.550]
# Episode:[769] reward:[26.748]
# Episode:[770] reward:[26.591]
# Episode:[771] reward:[27.136]
# Episode:[772] reward:[26.572]
# Episode:[773] reward:[26.173]
# Episode:[774] reward:[27.864]
# Episode:[775] reward:[27.493]
# Episode:[776] reward:[26.738]
# Episode:[777] reward:[26.642]
# Episode:[778] reward:[26.104]
# Episode:[779] reward:[26.917]
# Episode:[780] reward:[26.108]
# Episode:[781] reward:[27.245]
# Episode:[782] reward:[27.257]
# Episode:[783] reward:[26.232]
# Episode:[784] reward:[27.131]
# Episode:[785] reward:[26.175]
# Episode:[786] reward:[26.451]
# Episode:[787] reward:[26.071]
# Episode:[788] reward:[26.542]
# Episode:[789] reward:[26.879]
# Episode:[790] reward:[26.386]
# Episode:[791] reward:[26.420]
# Episode:[792] reward:[26.466]
# Episode:[793] reward:[27.409]
# Episode:[794] reward:[26.391]
# Episode:[795] reward:[27.204]
# Episode:[796] reward:[27.085]
# Episode:[797] reward:[26.670]
# Episode:[798] reward:[26.387]
# Episode:[799] reward:[26.482]
# Episode:[800] reward:[26.763]
# Episode:[801] reward:[26.731]
# Episode:[802] reward:[26.682]
# Episode:[803] reward:[26.317]
# Episode:[804] reward:[26.521]
# Episode:[805] reward:[26.216]
# Episode:[806] reward:[26.239]
# Episode:[807] reward:[26.357]
# Episode:[808] reward:[26.738]
# Episode:[809] reward:[26.659]
# Episode:[810] reward:[29.060]
# Episode:[811] reward:[26.746]
# Episode:[812] reward:[27.451]
# Episode:[813] reward:[26.633]
# Episode:[814] reward:[26.699]
# Episode:[815] reward:[26.369]
# Episode:[816] reward:[26.503]
# Episode:[817] reward:[26.731]
# Episode:[818] reward:[26.498]
# Episode:[819] reward:[26.735]
# Episode:[820] reward:[26.461]
# Episode:[821] reward:[26.879]
# Episode:[822] reward:[26.903]
# Episode:[823] reward:[26.889]
# Episode:[824] reward:[26.479]
# Episode:[825] reward:[26.534]
# Episode:[826] reward:[26.763]
# Episode:[827] reward:[26.458]
# Episode:[828] reward:[26.589]
# Episode:[829] reward:[27.789]
# Episode:[830] reward:[27.037]
# Episode:[831] reward:[26.536]
# Episode:[832] reward:[25.372]
# Episode:[833] reward:[26.360]
# Episode:[834] reward:[26.516]
# Episode:[835] reward:[27.855]
# Episode:[836] reward:[26.072]
# Episode:[837] reward:[26.737]
# Episode:[838] reward:[26.407]
# Episode:[839] reward:[26.564]
# Episode:[840] reward:[26.704]
# Episode:[841] reward:[26.112]
# Episode:[842] reward:[27.047]
# Episode:[843] reward:[26.520]
# Episode:[844] reward:[27.211]
# Episode:[845] reward:[27.032]
# Episode:[846] reward:[26.132]
# Episode:[847] reward:[26.515]
# Episode:[848] reward:[27.268]
# Episode:[849] reward:[26.478]
# Episode:[850] reward:[25.969]
# Episode:[851] reward:[26.339]
# Episode:[852] reward:[26.581]
# Episode:[853] reward:[26.529]
# Episode:[854] reward:[26.631]
# Episode:[855] reward:[26.606]
# Episode:[856] reward:[26.499]
# Episode:[857] reward:[26.597]
# Episode:[858] reward:[26.647]
# Episode:[859] reward:[26.539]
# Episode:[860] reward:[26.695]
# Episode:[861] reward:[26.507]
# Episode:[862] reward:[26.507]
# Episode:[863] reward:[26.459]
# Episode:[864] reward:[27.046]
# Episode:[865] reward:[26.918]
# Episode:[866] reward:[26.497]
# Episode:[867] reward:[27.013]
# Episode:[868] reward:[26.784]
# Episode:[869] reward:[26.494]
# Episode:[870] reward:[26.550]
# Episode:[871] reward:[26.843]
# Episode:[872] reward:[26.606]
# Episode:[873] reward:[26.685]
# Episode:[874] reward:[26.774]
# Episode:[875] reward:[27.102]
# Episode:[876] reward:[26.449]
# Episode:[877] reward:[26.461]
# Episode:[878] reward:[26.461]
# Episode:[879] reward:[26.562]
# Episode:[880] reward:[26.273]
# Episode:[881] reward:[26.847]
# Episode:[882] reward:[27.919]
# Episode:[883] reward:[27.791]
# Episode:[884] reward:[26.534]
# Episode:[885] reward:[26.505]
# Episode:[886] reward:[26.276]
# Episode:[887] reward:[25.754]
# Episode:[888] reward:[26.102]
# Episode:[889] reward:[26.344]
# Episode:[890] reward:[26.525]
# Episode:[891] reward:[26.459]
# Episode:[892] reward:[25.987]
# Episode:[893] reward:[25.461]
# Episode:[894] reward:[26.228]
# Episode:[895] reward:[25.591]
# Episode:[896] reward:[26.371]
# Episode:[897] reward:[26.500]
# Episode:[898] reward:[26.458]
# Episode:[899] reward:[26.142]
# Episode:[900] reward:[27.068]
# Episode:[901] reward:[25.681]
# Episode:[902] reward:[26.445]
# Episode:[903] reward:[25.935]
# Episode:[904] reward:[26.775]
# Episode:[905] reward:[26.641]
# Episode:[906] reward:[27.330]
# Episode:[907] reward:[26.475]
# Episode:[908] reward:[26.212]
# Episode:[909] reward:[26.588]
# Episode:[910] reward:[25.030]
# Episode:[911] reward:[26.817]
# Episode:[912] reward:[26.492]
# Episode:[913] reward:[26.465]
# Episode:[914] reward:[25.831]
# Episode:[915] reward:[26.580]
# Episode:[916] reward:[25.536]
# Episode:[917] reward:[25.905]
# Episode:[918] reward:[26.462]
# Episode:[919] reward:[26.471]
# Episode:[920] reward:[26.434]
# Episode:[921] reward:[27.560]
# Episode:[922] reward:[26.249]
# Episode:[923] reward:[26.420]
# Episode:[924] reward:[26.459]
# Episode:[925] reward:[26.623]
# Episode:[926] reward:[27.179]
# Episode:[927] reward:[26.360]
# Episode:[928] reward:[26.713]
# Episode:[929] reward:[26.377]
# Episode:[930] reward:[26.463]
# Episode:[931] reward:[26.035]
# Episode:[932] reward:[26.334]
# Episode:[933] reward:[27.181]
# Episode:[934] reward:[27.967]
# Episode:[935] reward:[26.468]
# Episode:[936] reward:[27.607]
# Episode:[937] reward:[26.624]
# Episode:[938] reward:[26.227]
# Episode:[939] reward:[26.499]
# Episode:[940] reward:[26.674]
# Episode:[941] reward:[26.147]
# Episode:[942] reward:[26.707]
# Episode:[943] reward:[26.498]
# Episode:[944] reward:[26.440]
# Episode:[945] reward:[26.874]
# Episode:[946] reward:[26.462]
# Episode:[947] reward:[27.524]
# Episode:[948] reward:[27.652]
# Episode:[949] reward:[27.970]
# Episode:[950] reward:[27.184]
# Episode:[951] reward:[27.704]
# Episode:[952] reward:[26.570]
# Episode:[953] reward:[25.937]
# Episode:[954] reward:[26.618]
# Episode:[955] reward:[27.313]
# Episode:[956] reward:[27.794]
# Episode:[957] reward:[27.381]
# Episode:[958] reward:[27.565]
# Episode:[959] reward:[26.867]
# Episode:[960] reward:[27.851]
# Episode:[961] reward:[25.182]
# Episode:[962] reward:[26.459]
# Episode:[963] reward:[26.486]
# Episode:[964] reward:[25.603]
# Episode:[965] reward:[26.173]
# Episode:[966] reward:[27.584]
# Episode:[967] reward:[26.501]
# Episode:[968] reward:[26.329]
# Episode:[969] reward:[25.249]
# Episode:[970] reward:[26.228]
# Episode:[971] reward:[26.585]
# Episode:[972] reward:[27.318]
# Episode:[973] reward:[26.108]
# Episode:[974] reward:[26.496]
# Episode:[975] reward:[26.152]
# Episode:[976] reward:[26.306]
# Episode:[977] reward:[26.139]
# Episode:[978] reward:[27.580]
# Episode:[979] reward:[27.720]
# Episode:[980] reward:[27.049]
# Episode:[981] reward:[26.910]
# Episode:[982] reward:[28.518]
# Episode:[983] reward:[29.098]
# Episode:[984] reward:[29.592]
# Episode:[985] reward:[26.484]
# Episode:[986] reward:[29.075]
# Episode:[987] reward:[26.194]
# Episode:[988] reward:[27.780]
# Episode:[989] reward:[27.597]
# Episode:[990] reward:[27.341]
# Episode:[991] reward:[27.028]
# Episode:[992] reward:[26.601]
# Episode:[993] reward:[26.213]
# Episode:[994] reward:[27.016]
# Episode:[995] reward:[25.009]
# Episode:[996] reward:[25.462]
# Episode:[997] reward:[26.824]
# Episode:[998] reward:[26.138]
# Episode:[999] reward:[25.074]
# Episode:[1000] reward:[26.646]

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline
print(len(agent.rewards))
plt.plot(np.array(agent.rewards))
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.title("RL Quadcopter")
plt.show()
# Out:
# 1000

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
# - 在task中制定任务为到达某一地点，奖励函数通过计算 “无人机” 与 “指定目的地” 的距离获取，包括以下3个部分：
# - 使用欧式距离
# - 利用clip函数将reward值限制在[-500, 500]之间，防止sigmoid函数溢出
# - 最后利用sigmoid函数将奖励值控制在[-1, 1]之间
# - 使用sigmoid函数是因为，sigmoid函数相对于DDPG Actor-critic更加友好，奖励函数会更加平滑
#
#
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
#
# - 我尝试了下DQN，但是效果并不好。所以我直接使用了项目二中提供的代码，尝试了Actor-Critic方法。Actor-Critic方法在调参过后表现更好；
# - 我把 gamma 设置为了0.9，降低了折扣率，减少了未来奖励；
# - 修改了Critic中Adam的lr=0.0001，降低了learning rate，默认是 0.001；
# - Actor中，沿用了原始的神经网络，使用了4层的神经网络，3个全连接层，relu做为激活函数，输出层sigmoid作为输出的激活函数；
# - Critic中，沿用了原始的神经网络，使用了2个全连接层和relu作为激活函数；
#
#
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：
# - 学习这个任务还是比较难的；
# - 刚开始的时候奖励会突然上升，第二次又马上回落，但最终收敛的话奖励都会趋于稳定；
# - 最后10次的奖励的平均值大概为：26.2
#
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：
# - 最难的部分应该是task中的奖励函数，我们需要根据任务自定义一个合适的奖励函数，其他部分的代码都已经提供了，只需要微调部分参数；
# - 应该是RL和前面其他的项目很不同，前面的项目问题比较明确，我们用TF和Keras可以很好的解决问题。但是RL需要我们自己去定义问题，然后再去解决；

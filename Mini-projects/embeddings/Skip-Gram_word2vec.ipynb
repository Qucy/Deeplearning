# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# c:\users\tracy\anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
#Sub-sampling

from collections import Counter
import random

threshold = 1e-5
words_counter = Counter(int_words)
total_count = len(int_words)
freds = {word: count/total_count for word, count in words_counter.items()}
pdrop = {word: 1 - np.sqrt(threshold/freds[word]) for word in words_counter}
train_words = [w for w in int_words if pdrop[w] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range 1 <= $R$ <= $C$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None], name='inputs')
    labels = tf.placeholder(tf.int32,[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From c:\users\tracy\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6480 0.0324 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6144 0.0265 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4861 0.0282 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6086 0.0294 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4965 0.0305 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5640 0.0267 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5881 0.0307 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5533 0.0282 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4692 0.0316 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4221 0.0285 sec/batch
# Nearest to all: klaproth, relative, side, houdini, osgood, inflows, tailor, knives,
# Nearest to however: vibrates, devolution, postures, blackhawks, correspond, ringling, aridity, vg,
# Nearest to he: bo, illustrate, thames, pegasus, kl, fueled, incised, three,
# Nearest to system: assumptions, dijon, garvey, nrc, emergency, goeldi, mawr, perfume,
# Nearest to some: missing, climbing, rajons, victimization, eeprom, either, physiological, empathic,
# Nearest to not: keynesian, gens, kaohsiung, fairey, communaut, ratchet, airliner, strangest,
# Nearest to many: ghz, lena, harar, bradley, commerzbank, arbitral, nox, geocaches,
# Nearest to or: oldcastle, collaboratively, unsound, bind, nazism, ascii, duomo, turnip,
# Nearest to recorded: omniscient, rolled, sopot, avram, upheaval, squadrons, travel, marburg,
# Nearest to grand: allegedly, cmf, chipset, moulin, rence, telamon, centripetal, katydids,
# Nearest to hold: bulmer, racks, hernia, winograd, decays, heaven, sculptors, lamanites,
# Nearest to prince: inductor, carved, qaida, nominees, plutonic, reining, muskie, subgenres,
# Nearest to hit: sewall, stereocenter, squealer, aught, ramifications, ron, ams, calories,
# Nearest to applied: narrowly, brower, baryogenesis, piped, facilitator, prenatal, lou, opto,
# Nearest to operations: verisimilitude, homology, metallurgy, heterogenous, counsellor, illustrative, mobs, forgiven,
# Nearest to consists: nisj, flank, eretz, vpns, fornax, uneducated, lebowski, pressing,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4945 0.0293 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3918 0.0301 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3273 0.0279 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2645 0.0300 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2031 0.0283 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1683 0.0269 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0831 0.0271 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0737 0.0237 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0070 0.0262 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9814 0.0265 sec/batch
# Nearest to all: relative, side, klaproth, dive, houdini, indispensable, interfere, releases,
# Nearest to however: correspond, devolution, stands, postures, composed, treaties, vibrates, blackhawks,
# Nearest to he: off, three, thames, fueled, illustrate, before, bodywork, nominal,
# Nearest to system: assumptions, emergency, dijon, scripts, garvey, basement, nrc, supplying,
# Nearest to some: computer, missing, either, climbing, kingdoms, physiological, risks, success,
# Nearest to not: keynesian, gens, designated, run, husband, commitment, which, com,
# Nearest to many: ghz, effect, bradley, lena, jordan, arbitral, talk, wide,
# Nearest to or: bind, collaboratively, leads, scientific, songs, unsound, ascii, jazz,
# Nearest to recorded: rolled, omniscient, travel, squadrons, upheaval, much, failure, mechanisms,
# Nearest to grand: allegedly, cmf, telamon, rence, chipset, pup, spiritually, katydids,
# Nearest to hold: heaven, use, weather, decays, bulmer, elevation, thirty, work,
# Nearest to prince: leave, carved, qaida, croats, reining, spain, nominees, plutonic,
# Nearest to hit: stereocenter, sewall, ron, calories, divest, ams, ore, aught,
# Nearest to applied: narrowly, prenatal, piped, brower, opto, cruithne, ruins, preference,
# Nearest to operations: metallurgy, ex, of, organizations, homology, observable, aspect, mobs,
# Nearest to consists: flank, nisj, got, fornax, rebel, eretz, pressing, mine,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9491 0.0260 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9134 0.0282 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8648 0.0303 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8542 0.0310 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8252 0.0284 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8202 0.0284 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7817 0.0304 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8042 0.0284 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8024 0.0265 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7805 0.0292 sec/batch
# Nearest to all: relative, klaproth, side, interfere, knives, dive, tailor, indispensable,
# Nearest to however: correspond, devolution, postures, stands, vg, composed, eclipse, vibrates,
# Nearest to he: fueled, illustrate, nominal, off, thames, theodore, nazarene, duke,
# Nearest to system: assumptions, emergency, dijon, basement, repair, scripts, mawr, flutes,
# Nearest to some: computer, risks, calculus, negatively, climbing, missing, either, kingdoms,
# Nearest to not: keynesian, gens, commitment, computing, breakdown, pony, criminals, kaohsiung,
# Nearest to many: ghz, bradley, effect, jordan, statistical, lena, arbitral, harar,
# Nearest to or: bind, collaboratively, nazism, scientific, leads, oldcastle, ascii, unsound,
# Nearest to recorded: rolled, omniscient, upheaval, travel, sopot, squadrons, migratory, dynamics,
# Nearest to grand: allegedly, cmf, telamon, pup, chipset, carolina, spiritually, moulin,
# Nearest to hold: decays, thirty, racks, weather, bulmer, elevation, heaven, vietnamese,
# Nearest to prince: spain, plutonic, nominees, carved, provocative, discounted, leave, croats,
# Nearest to hit: stereocenter, ron, sewall, calories, ams, divest, twins, ore,
# Nearest to applied: narrowly, prenatal, piped, cruithne, brower, amazement, lou, opto,
# Nearest to operations: metallurgy, homology, corridor, of, organizations, verisimilitude, aspect, forgiven,
# Nearest to consists: flank, nisj, fornax, eretz, pressing, rebel, nausea, resides,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7765 0.0276 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7384 0.0310 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7290 0.0297 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7237 0.0297 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7509 0.0315 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6880 0.0263 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6897 0.0297 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7143 0.0317 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7050 0.0262 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6760 0.0306 sec/batch
# Nearest to all: relative, klaproth, side, knives, interfere, tailor, inflows, telegraphy,
# Nearest to however: correspond, devolution, postures, vg, vibrates, aridity, ringling, blackhawks,
# Nearest to he: fueled, defeats, illustrate, nominal, nazarene, duke, off, anl,
# Nearest to system: assumptions, dijon, emergency, repair, basement, flutes, mawr, compound,
# Nearest to some: negatively, computer, risks, calculus, either, modesty, vesa, missing,
# Nearest to not: keynesian, breakdown, kaohsiung, gens, commitment, tegucigalpa, fines, criminals,
# Nearest to many: ghz, arbitral, bradley, effect, enjoyment, intergovernmental, openly, harar,
# Nearest to or: bind, nazism, unsound, leads, collaboratively, oldcastle, ascii, scientific,
# Nearest to recorded: omniscient, sopot, rolled, upheaval, migratory, travel, squadrons, much,
# Nearest to grand: allegedly, moulin, cmf, carolina, pup, chipset, stardom, rence,
# Nearest to hold: racks, decays, weather, hernia, heaven, stresses, bulmer, winograd,
# Nearest to prince: nominees, carved, spain, plutonic, qaida, reining, leave, financial,
# Nearest to hit: stereocenter, ron, sewall, twins, calories, ams, ramifications, divest,
# Nearest to applied: prenatal, narrowly, piped, cruithne, brower, facilitator, primaries, amazement,
# Nearest to operations: corridor, verisimilitude, homology, metallurgy, forgiven, of, sos, organizations,
# Nearest to consists: flank, nisj, eretz, fornax, nausea, resides, pressing, lebowski,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6558 0.0259 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6628 0.0265 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6100 0.0279 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6244 0.0277 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6320 0.0300 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6705 0.0302 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6002 0.0211 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5526 0.0310 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5005 0.0300 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5010 0.0272 sec/batch
# Nearest to all: relative, side, klaproth, knives, interfere, telegraphy, alloy, dive,
# Nearest to however: devolution, correspond, postures, aridity, vg, eclipse, blackhawks, vibrates,
# Nearest to he: defeats, vimes, anl, nazarene, timur, respondents, fueled, idempotent,
# Nearest to system: assumptions, emergency, dijon, repair, basement, flutes, compound, coordinate,
# Nearest to some: negatively, risks, computer, calculus, nor, either, lorna, protons,
# Nearest to not: kaohsiung, keynesian, breakdown, tegucigalpa, pony, fines, strangest, because,
# Nearest to many: ghz, arbitral, effect, enjoyment, establishments, intergovernmental, shatter, harar,
# Nearest to or: bind, unsound, leads, nazism, oldcastle, scientific, variations, collaboratively,
# Nearest to recorded: sopot, rolled, avram, omniscient, upheaval, squadrons, migratory, ccitt,
# Nearest to grand: moulin, cmf, allegedly, carolina, pup, centripetal, telamon, rence,
# Nearest to hold: racks, weather, bulmer, hernia, winograd, stresses, curriculum, hiragana,
# Nearest to prince: spain, nominees, plutonic, carved, qaida, subgenres, brink, slew,
# Nearest to hit: ron, sewall, stereocenter, twins, calories, ramifications, rock, divest,
# Nearest to applied: prenatal, piped, narrowly, cruithne, brower, facilitator, function, drugged,
# Nearest to operations: corridor, homology, verisimilitude, forgiven, metallurgy, of, illustrative, mysql,
# Nearest to consists: flank, nisj, eretz, fornax, resides, diarrhoea, vpns, lebowski,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4671 0.0295 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4983 0.0274 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4723 0.0275 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5520 0.0300 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5011 0.0324 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4828 0.0299 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4440 0.0300 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4091 0.0270 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4306 0.0308 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4235 0.0298 sec/batch
# Nearest to all: relative, side, klaproth, telegraphy, knives, interfere, alloy, indispensable,
# Nearest to however: devolution, correspond, aridity, postures, blackhawks, eclipse, vg, ringling,
# Nearest to he: vimes, defeats, respondents, anl, timur, idempotent, his, off,
# Nearest to system: assumptions, emergency, dijon, repair, basement, flutes, compound, sockets,
# Nearest to some: negatively, risks, either, nor, calculus, computer, protons, eeprom,
# Nearest to not: kaohsiung, which, because, keynesian, breakdown, strangest, parvati, pony,
# Nearest to many: ghz, arbitral, shatter, enjoyment, intergovernmental, returns, components, harar,
# Nearest to or: bind, unsound, leads, oldcastle, nazism, variations, transformations, scientific,
# Nearest to recorded: sopot, migratory, rolled, gcb, overeating, much, surrounding, avram,
# Nearest to grand: moulin, cmf, carolina, allegedly, stardom, centripetal, telamon, pup,
# Nearest to hold: weather, stresses, heaven, epp, winograd, racks, curriculum, bulmer,
# Nearest to prince: nominees, spain, plutonic, carved, croats, brink, subgenres, slew,
# Nearest to hit: ron, twins, rock, sewall, stereocenter, calories, corner, ramifications,
# Nearest to applied: prenatal, piped, cruithne, narrowly, facilitator, brower, readily, function,
# Nearest to operations: homology, corridor, verisimilitude, metallurgy, forgiven, oxidized, illustrative, organizations,
# Nearest to consists: flank, nisj, resides, fornax, vpns, eretz, privatisation, diarrhoea,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4268 0.0259 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4191 0.0290 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4260 0.0296 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3998 0.0295 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3931 0.0311 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4377 0.0279 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3715 0.0296 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3695 0.0280 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4364 0.0303 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3756 0.0297 sec/batch
# Nearest to all: side, relative, telegraphy, knives, klaproth, alloy, interfere, indispensable,
# Nearest to however: correspond, devolution, aridity, postures, vg, vibrates, ccny, eclipse,
# Nearest to he: defeats, his, vimes, respondents, anl, idempotent, timur, nazarene,
# Nearest to system: assumptions, repair, emergency, dijon, basement, printers, randomized, flutes,
# Nearest to some: negatively, nor, risks, either, furtherance, calculus, eeprom, rationality,
# Nearest to not: which, kaohsiung, parvati, tegucigalpa, bound, because, strangest, keynesian,
# Nearest to many: arbitral, ghz, enjoyment, returns, shatter, statistical, harar, owed,
# Nearest to or: bind, leads, unsound, nazism, oldcastle, achieve, transformations, variations,
# Nearest to recorded: sopot, much, gcb, grue, avram, wiccan, evangelic, rolled,
# Nearest to grand: moulin, cmf, carolina, allegedly, pup, centripetal, stardom, kidd,
# Nearest to hold: epp, stresses, heaven, weather, hernia, racks, winograd, curriculum,
# Nearest to prince: spain, plutonic, nominees, brink, croats, carved, family, slew,
# Nearest to hit: rock, sewall, twins, ron, stereocenter, calories, broadcasted, divest,
# Nearest to applied: prenatal, piped, cruithne, narrowly, brower, facilitator, readily, opto,
# Nearest to operations: homology, corridor, verisimilitude, metallurgy, elys, silicon, organizations, illustrative,
# Nearest to consists: flank, nisj, fornax, vpns, diarrhoea, eretz, resides, privatisation,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3996 0.0303 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3950 0.0292 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3664 0.0313 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3694 0.0317 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3803 0.0289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3620 0.0285 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3847 0.0257 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3694 0.0312 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3404 0.0257 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3727 0.0263 sec/batch
# Nearest to all: side, relative, telegraphy, knives, periodicity, indispensable, houdini, as,
# Nearest to however: correspond, devolution, aridity, vibrates, postures, ccny, vg, blackhawks,
# Nearest to he: his, defeats, anl, respondents, vimes, rashad, idempotent, theodore,
# Nearest to system: assumptions, emergency, dijon, flutes, randomized, mawr, repair, basement,
# Nearest to some: nor, risks, negatively, either, furtherance, rationality, calculus, lorna,
# Nearest to not: kaohsiung, parvati, which, bound, is, because, immoral, strangest,
# Nearest to many: arbitral, owed, returns, harar, intergovernmental, ghz, shatter, enjoyment,
# Nearest to or: bind, leads, digs, oldcastle, unsound, nazism, externalized, variations,
# Nearest to recorded: sopot, much, surrounding, wiccan, avram, grue, gcb, cimmerian,
# Nearest to grand: moulin, cmf, carolina, centripetal, allegedly, pup, stardom, kidd,
# Nearest to hold: epp, stresses, heaven, weather, hernia, winograd, hydrocarbon, disintegrated,
# Nearest to prince: spain, plutonic, brink, croats, carved, nominees, family, slew,
# Nearest to hit: rock, ron, twins, sewall, track, calories, stereocenter, divest,
# Nearest to applied: prenatal, cruithne, piped, brower, narrowly, opto, facilitator, because,
# Nearest to operations: homology, verisimilitude, corridor, organizations, helicopters, elys, compliance, oxidized,
# Nearest to consists: nisj, flank, resides, fornax, vpns, eretz, privatisation, diarrhoea,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3505 0.0287 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2886 0.0296 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3862 0.0308 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3615 0.0266 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3767 0.0292 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3040 0.0272 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2933 0.0286 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3597 0.0301 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2072 0.0285 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3095 0.0312 sec/batch
# Nearest to all: side, relative, inferences, knives, periodicity, bobbin, maximus, houdini,
# Nearest to however: correspond, aridity, devolution, vibrates, videography, ccny, postures, vg,
# Nearest to he: his, anl, defeats, respondents, before, idempotent, off, nazarene,
# Nearest to system: assumptions, dijon, emergency, flutes, randomized, repair, mawr, basement,
# Nearest to some: nor, either, risks, rationality, furtherance, negatively, calculus, susannah,
# Nearest to not: which, parvati, kaohsiung, immoral, because, typical, proven, keynesian,
# Nearest to many: arbitral, shatter, owed, establishments, enjoyment, ghz, intergovernmental, geocaches,
# Nearest to or: leads, bind, unsound, nazism, externalized, digs, zetalisp, oldcastle,
# Nearest to recorded: sopot, much, migratory, gcb, surrounding, grue, wiccan, wereman,
# Nearest to grand: moulin, cmf, carolina, centripetal, wigan, stone, pup, allegedly,
# Nearest to hold: epp, weather, stresses, heaven, hernia, winograd, disintegrated, racks,
# Nearest to prince: spain, plutonic, croats, brink, nominees, muskie, aunt, carved,
# Nearest to hit: rock, twins, sewall, track, ron, stereocenter, calories, ams,
# Nearest to applied: prenatal, cruithne, piped, facilitator, opto, brower, narrowly, readily,
# Nearest to operations: homology, verisimilitude, corridor, aviation, organizations, helicopters, compliance, metallurgy,
# Nearest to consists: nisj, flank, resides, vpns, fornax, zimbabwe, privatisation, eretz,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3179 0.0275 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2926 0.0280 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3302 0.0147 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2629 0.0297 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2410 0.0306 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2346 0.0283 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1965 0.0295 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2100 0.0289 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1892 0.0299 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2020 0.0304 sec/batch
# Nearest to all: side, relative, inferences, periodicity, bobbin, as, maximus, knives,
# Nearest to however: aridity, correspond, blackhawks, vibrates, videography, eclipse, devolution, postures,
# Nearest to he: his, anl, defeats, respondents, nazarene, idempotent, extinguish, said,
# Nearest to system: assumptions, emergency, dijon, amdahl, flutes, basement, printers, mawr,
# Nearest to some: risks, either, nor, negatively, rationality, eeprom, furtherance, edifice,
# Nearest to not: because, immoral, parvati, kaohsiung, typical, which, tegucigalpa, keynesian,
# Nearest to many: arbitral, establishments, shatter, intergovernmental, ghz, contorted, owed, inkwell,
# Nearest to or: bind, leads, unsound, externalized, digs, nazism, zetalisp, bilirubin,
# Nearest to recorded: sopot, much, performed, grue, wiccan, prematurely, wereman, compilation,
# Nearest to grand: moulin, cmf, carolina, centripetal, arta, stone, siegfried, allegedly,
# Nearest to hold: epp, heaven, weather, disintegrated, winograd, stresses, racks, duarte,
# Nearest to prince: spain, croats, plutonic, brink, muskie, carved, aunt, oxley,
# Nearest to hit: rock, twins, track, sewall, ron, divest, calories, broadcasted,
# Nearest to applied: cruithne, prenatal, opto, facilitator, piped, brower, algemeen, narrowly,
# Nearest to operations: homology, verisimilitude, corridor, aviation, helicopters, illustrative, organizations, silicon,
# Nearest to consists: flank, resides, vpns, nisj, zimbabwe, crossing, fornax, norfolk,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2631 0.0310 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2036 0.0310 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2015 0.0290 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1459 0.0271 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1895 0.0292 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1554 0.0305 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1873 0.0302 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1735 0.0284 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2041 0.0264 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1629 0.0293 sec/batch
# Nearest to all: side, relative, as, animatronic, inferences, periodicity, indispensable, knives,
# Nearest to however: aridity, correspond, videography, devolution, postures, vg, eclipse, blackhawks,
# Nearest to he: his, anl, off, defeats, idempotent, vimes, extinguish, said,
# Nearest to system: assumptions, amdahl, coordinate, printers, flutes, emergency, dijon, basement,
# Nearest to some: risks, nor, either, rationality, eeprom, furtherance, negatively, inconsistency,
# Nearest to not: because, which, parvati, immoral, typical, proven, kaohsiung, is,
# Nearest to many: arbitral, ghz, shatter, establishments, contorted, statistical, intergovernmental, owed,
# Nearest to or: bind, unsound, leads, are, turnip, digs, externalized, depending,
# Nearest to recorded: sopot, much, compilation, grue, performed, migratory, promo, robins,
# Nearest to grand: moulin, cmf, carolina, arta, kidd, wigan, pup, siegfried,
# Nearest to hold: heaven, weather, epp, racks, subtext, disintegrated, hernia, dyadic,
# Nearest to prince: plutonic, croats, spain, oxley, carved, brink, muskie, slew,
# Nearest to hit: rock, twins, track, sewall, divest, ron, calories, fans,
# Nearest to applied: cruithne, prenatal, opto, facilitator, piped, brower, narrowly, baryogenesis,
# Nearest to operations: homology, aviation, corridor, verisimilitude, helicopters, organizations, compliance, ethologist,
# Nearest to consists: resides, flank, vpns, nisj, zimbabwe, fornax, crossing, bicameral,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1870 0.0285 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2329 0.0330 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1880 0.0292 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1562 0.0303 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1934 0.0320 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1816 0.0276 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1925 0.0302 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1538 0.0290 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1310 0.0316 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1867 0.0320 sec/batch
# Nearest to all: relative, as, side, periodicity, inferences, indispensable, moralia, maximus,
# Nearest to however: vg, aridity, correspond, postures, devolution, videography, anatomic, vibrates,
# Nearest to he: his, anl, defeats, off, theodore, vimes, idempotent, extinguish,
# Nearest to system: assumptions, amdahl, coordinate, emergency, flutes, printers, hierarchical, provide,
# Nearest to some: risks, nor, either, rationality, furtherance, irwell, oat, calculus,
# Nearest to not: which, because, typical, parvati, is, immoral, kaohsiung, totient,
# Nearest to many: arbitral, owed, establishments, intergovernmental, shatter, contorted, geocaches, ghz,
# Nearest to or: bind, unsound, leads, are, digs, externalized, mitigated, turnip,
# Nearest to recorded: sopot, much, compilation, migratory, wereman, promo, grue, performed,
# Nearest to grand: moulin, cmf, carolina, centripetal, kidd, pup, stone, wigan,
# Nearest to hold: epp, heaven, weather, subtext, hydrocarbon, disintegrated, stresses, racks,
# Nearest to prince: plutonic, croats, brink, oxley, singhasari, spain, slew, aunt,
# Nearest to hit: track, rock, sewall, twins, divest, ams, calories, broadcasted,
# Nearest to applied: cruithne, prenatal, opto, facilitator, brower, narrowly, piped, algemeen,
# Nearest to operations: homology, aviation, verisimilitude, corridor, helicopters, organizations, compliance, bgcolor,
# Nearest to consists: resides, vpns, flank, nisj, crossing, zimbabwe, bicameral, fornax,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1959 0.0296 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1455 0.0284 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1526 0.0286 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1667 0.0302 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1740 0.0277 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1399 0.0312 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1871 0.0282 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1272 0.0300 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2007 0.0308 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2273 0.0302 sec/batch
# Nearest to all: periodicity, maximus, side, relative, animatronic, inferences, moralia, as,
# Nearest to however: aridity, vg, vibrates, devolution, videography, eclipse, had, correspond,
# Nearest to he: his, anl, defeats, off, was, career, extinguish, theodore,
# Nearest to system: assumptions, amdahl, mawr, emergency, dijon, combatted, coordinate, hierarchical,
# Nearest to some: risks, furtherance, nor, rationality, either, victimization, susannah, inconsistency,
# Nearest to not: immoral, parvati, because, typical, which, marriage, is, fines,
# Nearest to many: arbitral, owed, anglican, intergovernmental, geocaches, subtle, notably, shatter,
# Nearest to or: bind, unsound, nazism, tria, digs, leads, mitigated, externalized,
# Nearest to recorded: much, sopot, compilation, migratory, bands, brockovich, performed, wereman,
# Nearest to grand: moulin, cmf, carolina, centripetal, kidd, pup, wigan, stone,
# Nearest to hold: epp, heaven, weather, subtext, narrowly, hydrocarbon, racks, hernia,
# Nearest to prince: plutonic, oxley, croats, slew, muskie, singhasari, carved, spain,
# Nearest to hit: track, sewall, rock, ams, twins, ron, abduct, divest,
# Nearest to applied: cruithne, prenatal, opto, facilitator, brower, algemeen, narrowly, baryogenesis,
# Nearest to operations: homology, aviation, helicopters, verisimilitude, corridor, organizations, compliance, ethologist,
# Nearest to consists: vpns, resides, bicameral, flank, nisj, crossing, fornax, zimbabwe,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2192 0.0320 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1412 0.0279 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1564 0.0312 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1398 0.0275 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0508 0.0273 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1484 0.0285 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1401 0.0285 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1381 0.0265 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1787 0.0053 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1050 0.0312 sec/batch
# Nearest to all: relative, periodicity, animatronic, side, inferences, as, maximus, fastest,
# Nearest to however: aridity, vg, vibrates, videography, devolution, postures, correspond, eclipse,
# Nearest to he: his, anl, off, defeats, extinguish, career, retired, theodore,
# Nearest to system: assumptions, amdahl, dijon, nls, emergency, interface, poorly, latencies,
# Nearest to some: risks, furtherance, either, rationality, nor, edifice, victimization, nanosystems,
# Nearest to not: because, typical, immoral, parvati, marriage, is, that, totient,
# Nearest to many: arbitral, shatter, notably, intergovernmental, establishments, geocaches, owed, wide,
# Nearest to or: unsound, bind, are, leads, externalized, tria, mitigated, digs,
# Nearest to recorded: compilation, much, sopot, migratory, bands, brockovich, promo, wereman,
# Nearest to grand: moulin, cmf, carolina, wigan, kidd, centripetal, competences, admiring,
# Nearest to hold: epp, weather, heaven, narrowly, winograd, subtext, duarte, hydrocarbon,
# Nearest to prince: plutonic, oxley, croats, muskie, slew, singhasari, spain, brink,
# Nearest to hit: track, sewall, rock, twins, fans, abduct, ams, squealer,
# Nearest to applied: cruithne, prenatal, opto, facilitator, brower, narrowly, algemeen, readily,
# Nearest to operations: homology, aviation, helicopters, verisimilitude, organizations, corridor, bgcolor, compliance,
# Nearest to consists: bicameral, vpns, resides, flank, crossing, nisj, zimbabwe, chancery,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0827 0.0319 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0850 0.0325 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0808 0.0280 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0471 0.0283 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0762 0.0275 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0017 0.0306 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1159 0.0253 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1061 0.0273 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1184 0.0263 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0603 0.0272 sec/batch
# Nearest to all: relative, animatronic, side, periodicity, maximus, batting, federations, underrepresented,
# Nearest to however: aridity, socialist, devolution, videography, blackhawks, vibrates, eclipse, anatomic,
# Nearest to he: his, anl, defeats, off, extinguish, honorably, before, jolla,
# Nearest to system: assumptions, amdahl, emergency, combatted, dijon, nls, poorly, coordinate,
# Nearest to some: risks, either, edifice, furtherance, typical, lectionis, rationality, nor,
# Nearest to not: typical, because, is, immoral, parvati, marriage, that, which,
# Nearest to many: notably, owed, intergovernmental, shatter, geocaches, arbitral, establishments, ghz,
# Nearest to or: unsound, are, bind, externalized, digs, depending, mitigated, turnip,
# Nearest to recorded: compilation, sopot, much, migratory, proceeding, bands, brockovich, wereman,
# Nearest to grand: moulin, cmf, wigan, carolina, centripetal, kidd, spectacular, siegfried,
# Nearest to hold: weather, narrowly, subtext, heaven, epp, showdown, hydrocarbon, racks,
# Nearest to prince: plutonic, oxley, slew, croats, muskie, singhasari, carved, inherited,
# Nearest to hit: track, sewall, ams, twins, rock, abduct, straight, fans,
# Nearest to applied: cruithne, prenatal, facilitator, opto, brower, algemeen, narrowly, baryogenesis,
# Nearest to operations: homology, aviation, helicopters, verisimilitude, bgcolor, organizations, efe, sos,
# Nearest to consists: bicameral, vpns, resides, crossing, flank, nisj, chancery, shogunate,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0199 0.0313 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0314 0.0270 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9991 0.0274 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0748 0.0299 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0865 0.0282 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0603 0.0256 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0732 0.0285 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0897 0.0274 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0332 0.0265 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0502 0.0279 sec/batch
# Nearest to all: periodicity, as, relative, inferences, animatronic, maximus, dcs, side,
# Nearest to however: aridity, vg, videography, correspond, vibrates, eclipse, anatomic, nepotism,
# Nearest to he: his, anl, career, housewife, off, honorably, theodore, jolla,
# Nearest to system: assumptions, amdahl, coordinate, combatted, emergency, poorly, dijon, interface,
# Nearest to some: either, risks, furtherance, lectionis, nor, inconsistency, rationality, spurious,
# Nearest to not: is, because, typical, parvati, immoral, which, that, marriage,
# Nearest to many: owed, notably, shatter, intergovernmental, arbitral, anglican, geocaches, lovers,
# Nearest to or: are, unsound, digs, benzoate, bind, externalized, mitigated, depending,
# Nearest to recorded: compilation, much, sopot, migratory, bands, proceeding, wereman, hits,
# Nearest to grand: moulin, cmf, centripetal, kidd, wigan, carolina, competences, siegfried,
# Nearest to hold: subtext, weather, heaven, showdown, narrowly, epp, winograd, racks,
# Nearest to prince: plutonic, oxley, croats, slew, muskie, singhasari, carved, selina,
# Nearest to hit: ams, rock, track, sewall, abduct, twins, divest, bingu,
# Nearest to applied: cruithne, prenatal, opto, facilitator, algemeen, brower, baryogenesis, readily,
# Nearest to operations: homology, aviation, verisimilitude, helicopters, organizations, bgcolor, normalization, compliance,
# Nearest to consists: bicameral, resides, vpns, crossing, chancery, nisj, flank, shogunate,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0644 0.0326 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0632 0.0287 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0846 0.0289 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0826 0.0312 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0538 0.0309 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0548 0.0276 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0727 0.0294 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0503 0.0274 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0773 0.0302 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0901 0.0294 sec/batch
# Nearest to all: periodicity, federations, animatronic, underrepresented, maximus, relative, as, inferences,
# Nearest to however: aridity, videography, vg, eclipse, had, devolution, nepotism, correspond,
# Nearest to he: his, anl, jolla, off, defeats, career, honorably, died,
# Nearest to system: assumptions, amdahl, combatted, coordinate, emergency, flutes, poorly, mawr,
# Nearest to some: furtherance, either, lectionis, nor, inconsistency, risks, edifice, alfred,
# Nearest to not: because, is, parvati, immoral, typical, marriage, kaohsiung, that,
# Nearest to many: owed, notably, shatter, anglican, geocaches, arbitral, intergovernmental, lovers,
# Nearest to or: are, digs, unsound, benzoate, externalized, tria, mitigated, matsya,
# Nearest to recorded: compilation, much, sopot, proceeding, migratory, topic, cimmerian, wereman,
# Nearest to grand: moulin, cmf, centripetal, competences, kidd, gyoku, admiring, destabilization,
# Nearest to hold: heaven, subtext, narrowly, showdown, epp, weather, duarte, vinland,
# Nearest to prince: plutonic, oxley, croats, inherited, slew, singhasari, brother, dukedom,
# Nearest to hit: ams, sewall, track, divest, rock, bingu, misskelley, abduct,
# Nearest to applied: cruithne, facilitator, prenatal, opto, algemeen, brower, narrowly, readily,
# Nearest to operations: homology, aviation, helicopters, verisimilitude, bgcolor, organizations, efe, ingres,
# Nearest to consists: bicameral, resides, vpns, chancery, flank, norfolk, nisj, shogunate,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0442 0.0280 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0323 0.0288 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0343 0.0271 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0685 0.0288 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0658 0.0303 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1382 0.0287 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1266 0.0311 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0472 0.0305 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0373 0.0262 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0462 0.0284 sec/batch
# Nearest to all: periodicity, animatronic, federations, relative, underrepresented, dcs, inferences, maximus,
# Nearest to however: videography, aridity, vg, eclipse, vibrates, correspond, devolution, had,
# Nearest to he: his, anl, jolla, housewife, career, off, before, extinguish,
# Nearest to system: assumptions, amdahl, combatted, emergency, poorly, dijon, interface, coordinate,
# Nearest to some: furtherance, either, lectionis, risks, nor, victimization, inconsistency, rationality,
# Nearest to not: because, is, typical, marriage, parvati, which, totient, immoral,
# Nearest to many: notably, owed, geocaches, arbitral, intergovernmental, shatter, lovers, anglican,
# Nearest to or: are, unsound, benzoate, tria, depending, externalized, digs, mitigated,
# Nearest to recorded: compilation, much, sopot, migratory, brockovich, cimmerian, wereman, bands,
# Nearest to grand: moulin, cmf, competences, centripetal, destabilization, gyoku, duchy, admiring,
# Nearest to hold: heaven, subtext, weather, showdown, narrowly, vinland, duarte, epp,
# Nearest to prince: plutonic, oxley, slew, croats, brother, eldest, inherited, devereux,
# Nearest to hit: ams, sewall, track, rock, divest, penderecki, compilation, bingu,
# Nearest to applied: cruithne, facilitator, prenatal, opto, algemeen, brower, readily, narrowly,
# Nearest to operations: homology, aviation, helicopters, verisimilitude, bgcolor, efe, ethologist, normalization,
# Nearest to consists: bicameral, resides, vpns, chancery, flank, shogunate, crossing, representatives,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0148 0.0310 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0287 0.0260 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0435 0.0289 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0202 0.0282 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0483 0.0289 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0268 0.0270 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0090 0.0313 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9779 0.0285 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0078 0.0256 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9669 0.0285 sec/batch
# Nearest to all: periodicity, relative, animatronic, federations, underrepresented, dcs, inferences, maximus,
# Nearest to however: aridity, vg, videography, had, eclipse, vibrates, devolution, anatomic,
# Nearest to he: his, anl, died, later, said, jolla, was, extinguish,
# Nearest to system: amdahl, assumptions, combatted, interface, nls, dijon, poorly, emergency,
# Nearest to some: furtherance, either, risks, nor, susannah, lectionis, spurious, speeches,
# Nearest to not: because, marriage, is, immoral, that, typical, parvati, which,
# Nearest to many: notably, owed, geocaches, intergovernmental, shatter, ghz, and, arbitral,
# Nearest to or: unsound, digs, benzoate, matsya, are, tria, mitigated, externalized,
# Nearest to recorded: compilation, sopot, much, brockovich, migratory, proceeding, wereman, hits,
# Nearest to grand: moulin, centripetal, competences, cmf, gyoku, duchy, destabilization, siegfried,
# Nearest to hold: heaven, subtext, weather, curriculum, narrowly, vinland, chains, showdown,
# Nearest to prince: oxley, plutonic, brother, slew, eldest, croats, inherited, devereux,
# Nearest to hit: ams, sewall, penderecki, rock, track, divest, misskelley, abduct,
# Nearest to applied: cruithne, prenatal, facilitator, algemeen, opto, readily, brower, baryogenesis,
# Nearest to operations: homology, aviation, helicopters, bgcolor, efe, bead, verisimilitude, gcd,
# Nearest to consists: bicameral, resides, vpns, chancery, flank, shogunate, representatives, crossing,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0162 0.0306 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9454 0.0317 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0056 0.0282 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0384 0.0259 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0240 0.0272 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0055 0.0257 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9233 0.0267 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9683 0.0310 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9446 0.0297 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9963 0.0279 sec/batch
# Nearest to all: periodicity, federations, animatronic, as, dcs, relative, batting, subsets,
# Nearest to however: vg, aridity, videography, eclipse, socialist, vibrates, correspond, anatomic,
# Nearest to he: his, off, anl, jolla, extinguish, died, housewife, before,
# Nearest to system: assumptions, amdahl, combatted, dijon, nls, poorly, emergency, sinaltrainal,
# Nearest to some: either, furtherance, risks, spurious, lectionis, nor, typical, tuning,
# Nearest to not: is, because, typical, marriage, parvati, to, which, incestuous,
# Nearest to many: notably, owed, geocaches, and, ghz, intergovernmental, lovers, wide,
# Nearest to or: are, unsound, benzoate, depending, mitigated, matsya, externalized, is,
# Nearest to recorded: compilation, much, sopot, proceeding, migratory, wereman, brockovich, hits,
# Nearest to grand: moulin, centripetal, cmf, competences, destabilization, spectacular, duchy, gyoku,
# Nearest to hold: subtext, heaven, showdown, chains, sld, narrowly, weather, vinland,
# Nearest to prince: plutonic, oxley, slew, croats, fugues, muskie, selina, brother,
# Nearest to hit: ams, straight, rock, hitters, bingu, penderecki, sewall, divest,
# Nearest to applied: cruithne, opto, prenatal, facilitator, brower, algemeen, baryogenesis, readily,
# Nearest to operations: homology, aviation, helicopters, bgcolor, efe, normalization, gcd, verisimilitude,
# Nearest to consists: bicameral, resides, vpns, representatives, shogunate, chancery, crossing, nisj,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0029 0.0304 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9819 0.0285 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9675 0.0270 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9964 0.0263 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0601 0.0295 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9505 0.0285 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0072 0.0292 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0175 0.0289 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0157 0.0300 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9983 0.0270 sec/batch
# Nearest to all: federations, as, periodicity, dcs, animatronic, own, underrepresented, inferences,
# Nearest to however: vg, videography, aridity, socialist, correspond, vibrates, for, anatomic,
# Nearest to he: his, jolla, anl, died, later, career, off, educated,
# Nearest to system: amdahl, assumptions, combatted, nls, emergency, sinaltrainal, coordinate, poorly,
# Nearest to some: either, furtherance, risks, lectionis, spurious, nor, typical, susannah,
# Nearest to not: is, because, marriage, parvati, typical, which, that, to,
# Nearest to many: lovers, owed, notably, geocaches, intergovernmental, ghz, shatter, wide,
# Nearest to or: are, unsound, benzoate, depending, matsya, digs, with, tria,
# Nearest to recorded: compilation, much, sopot, records, proceeding, brockovich, wereman, besieges,
# Nearest to grand: moulin, centripetal, competences, cmf, destabilization, duchy, leadbelly, gyoku,
# Nearest to hold: showdown, subtext, heaven, chains, narrowly, sld, weather, curriculum,
# Nearest to prince: plutonic, oxley, slew, granddaughter, eldest, brother, devereux, singhasari,
# Nearest to hit: ams, track, rock, hitters, divest, compilation, sewall, penderecki,
# Nearest to applied: cruithne, opto, facilitator, prenatal, brower, algemeen, baryogenesis, readily,
# Nearest to operations: homology, aviation, helicopters, bgcolor, efe, normalization, organizations, abacus,
# Nearest to consists: bicameral, resides, vpns, chancery, shogunate, representatives, cowan, fornax,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0198 0.0289 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9893 0.0300 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9878 0.0285 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0022 0.0276 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0090 0.0312 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0081 0.0282 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9586 0.0280 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9613 0.0294 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9640 0.0297 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0422 0.0299 sec/batch
# Nearest to all: federations, periodicity, as, own, animatronic, maximus, underrepresented, non,
# Nearest to however: vg, videography, aridity, socialist, for, correspond, vibrates, anatomic,
# Nearest to he: his, jolla, anl, later, off, career, educated, housewife,
# Nearest to system: combatted, amdahl, assumptions, emergency, sinaltrainal, nls, dijon, mawr,
# Nearest to some: furtherance, either, risks, lectionis, without, nor, rationality, specifically,
# Nearest to not: is, which, marriage, because, parvati, that, obstinate, typical,
# Nearest to many: notably, lovers, geocaches, owed, arbitral, ghz, wide, shatter,
# Nearest to or: are, matsya, benzoate, is, unsound, mitigated, externalized, depending,
# Nearest to recorded: compilation, much, sopot, proceeding, besieges, cimmerian, records, wereman,
# Nearest to grand: moulin, centripetal, competences, cmf, leadbelly, destabilization, kidd, gyoku,
# Nearest to hold: subtext, showdown, heaven, chains, narrowly, sld, vinland, midwestern,
# Nearest to prince: oxley, plutonic, slew, eldest, granddaughter, brother, inherited, pilar,
# Nearest to hit: ams, sewall, hitters, penderecki, track, rock, entrainment, bingu,
# Nearest to applied: cruithne, facilitator, opto, prenatal, brower, algemeen, readily, baryogenesis,
# Nearest to operations: homology, aviation, helicopters, bgcolor, normalization, organizations, abacus, joint,
# Nearest to consists: bicameral, resides, vpns, representatives, shogunate, chancery, bundesland, comprising,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9756 0.0290 sec/batch
# ...
# Nearest to all: non, are, own, as, every, there, seven, a,
# Nearest to however: for, soared, by, was, decade, the, after, modernization,
# Nearest to he: his, himself, later, career, got, jolla, housewife, him,
# Nearest to system: systems, communicative, nls, combatted, sinaltrainal, pts, essais, valiente,
# Nearest to some: interestingly, without, spurious, been, while, pcm, are, durer,
# Nearest to not: to, but, is, that, it, be, a, because,
# Nearest to many: notably, and, most, more, including, among, in, as,
# Nearest to or: is, a, are, to, the, with, if, an,
# Nearest to recorded: compilation, records, besieges, found, jeu, madeline, much, brockovich,
# Nearest to grand: moulin, centripetal, competences, destabilization, admiring, knights, prix, northeastern,
# Nearest to hold: subtext, heaven, showdown, chains, halberd, ozzie, cosets, sld,
# Nearest to prince: oxley, granddaughter, rainier, sadr, essaioi, sensing, miko, hashihito,
# Nearest to hit: ams, hitters, break, fielding, track, prominence, entrainment, ranatunga,
# Nearest to applied: facilitator, opto, brower, cruithne, fpgas, prenatal, flavor, ize,
# Nearest to operations: homology, bead, abacus, fencepost, resents, gcd, normalization, peacekeeping,
# Nearest to consists: bicameral, resides, bundesland, ordinaries, comprising, vpns, representatives, chancery,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8446 0.0307 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8640 0.0302 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8717 0.0287 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8574 0.0305 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8685 0.0276 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8852 0.0309 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8536 0.0279 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8444 0.0285 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8732 0.0287 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8422 0.0302 sec/batch
# Nearest to all: non, are, own, there, as, every, seven, groups,
# Nearest to however: was, by, soared, for, modernization, after, vg, rather,
# Nearest to he: his, later, was, himself, career, educated, studied, jolla,
# Nearest to system: systems, communicative, combatted, nls, sinaltrainal, psionic, due, albumin,
# Nearest to some: interestingly, without, spurious, been, are, in, specifically, pcm,
# Nearest to not: to, is, but, that, be, because, it, in,
# Nearest to many: notably, most, and, more, including, as, wide, among,
# Nearest to or: a, is, are, to, the, if, with, of,
# Nearest to recorded: compilation, records, besieges, cimmerian, jeu, madeline, brockovich, merengue,
# Nearest to grand: moulin, centripetal, competences, destabilization, prix, admiring, knights, northeastern,
# Nearest to hold: heaven, subtext, showdown, chains, halberd, cosets, barnard, midwestern,
# Nearest to prince: granddaughter, soga, oxley, miko, hashihito, rainier, bidatsu, brother,
# Nearest to hit: ams, hitters, track, prominence, break, fielding, misskelley, ranatunga,
# Nearest to applied: facilitator, opto, brower, cruithne, extinguish, fpgas, ize, prenatal,
# Nearest to operations: homology, bead, gcd, resents, abacus, peacekeeping, normalization, fencepost,
# Nearest to consists: bicameral, resides, bundesland, ordinaries, representatives, comprising, nicaraguan, elaborates,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8858 0.0292 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8490 0.0300 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8561 0.0297 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8265 0.0302 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9078 0.0289 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8503 0.0269 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9816 0.0274 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9071 0.0311 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9227 0.0299 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8162 0.0314 sec/batch
# Nearest to all: own, are, non, every, as, there, seven, four,
# Nearest to however: was, for, soared, by, vg, modernization, the, after,
# Nearest to he: his, later, was, school, himself, studied, housewife, educated,
# Nearest to system: systems, combatted, communicative, sinaltrainal, majoritarian, eldorado, psionic, nls,
# Nearest to some: interestingly, without, been, specifically, are, spurious, pcm, durer,
# Nearest to not: to, is, but, that, a, it, because, be,
# Nearest to many: notably, and, most, including, number, more, among, lovers,
# Nearest to or: a, is, the, to, are, if, of, not,
# Nearest to recorded: compilation, records, besieges, cimmerian, madeline, brockovich, biographies, verdeans,
# Nearest to grand: competences, moulin, centripetal, destabilization, prix, admiring, northeastern, knights,
# Nearest to hold: heaven, subtext, chains, showdown, curriculum, cosets, midwestern, barnard,
# Nearest to prince: granddaughter, oxley, soga, miko, rainier, sensing, sadr, hashihito,
# Nearest to hit: ams, hitters, prominence, break, penderecki, track, ranatunga, misskelley,
# Nearest to applied: facilitator, opto, brower, cruithne, trinity, prenatal, fpgas, extinguish,
# Nearest to operations: homology, bead, resents, abacus, gcd, peacekeeping, normalization, fencepost,
# Nearest to consists: bicameral, bundesland, resides, ordinaries, comprising, tempore, head, chancery,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7807 0.0306 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8555 0.0289 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8219 0.0277 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8933 0.0292 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8467 0.0282 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8526 0.0309 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9065 0.0154 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7851 0.0301 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8260 0.0249 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8681 0.0336 sec/batch
# Nearest to all: own, non, are, as, every, have, there, a,
# Nearest to however: by, was, for, the, soared, vg, modernization, decade,
# Nearest to he: his, was, himself, later, him, studied, got, before,
# Nearest to system: systems, communicative, combatted, sinaltrainal, nls, albumin, psionic, eldorado,
# Nearest to some: interestingly, been, while, spurious, are, specifically, without, cave,
# Nearest to not: to, that, but, is, it, because, in, a,
# Nearest to many: most, notably, and, including, more, among, are, as,
# Nearest to or: is, a, the, are, of, to, with, matsya,
# Nearest to recorded: compilation, records, besieges, cimmerian, madeline, brockovich, boneshaker, wereman,
# Nearest to grand: moulin, centripetal, prix, competences, destabilization, admiring, northeastern, knights,
# Nearest to hold: subtext, chains, heaven, cosets, showdown, redfield, curriculum, halberd,
# Nearest to prince: granddaughter, oxley, rainier, soga, miko, sirmium, sadr, hashihito,
# Nearest to hit: ams, prominence, hitters, track, break, penderecki, misskelley, promo,
# Nearest to applied: facilitator, brower, opto, cruithne, trinity, extinguish, fpgas, prenatal,
# Nearest to operations: bead, homology, abacus, resents, gcd, peacekeeping, normalization, fencepost,
# Nearest to consists: bicameral, resides, bundesland, ordinaries, newborns, chancery, head, comprising,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8182 0.0277 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8311 0.0292 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8357 0.0281 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7902 0.0293 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8760 0.0284 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8070 0.0297 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9004 0.0307 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7716 0.0304 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8288 0.0276 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8022 0.0303 sec/batch
# Nearest to all: are, own, every, as, non, a, is, the,
# Nearest to however: soared, for, was, by, after, vg, the, non,
# Nearest to he: his, himself, later, got, was, career, studied, school,
# Nearest to system: systems, communicative, combatted, sinaltrainal, albumin, majoritarian, nls, releasing,
# Nearest to some: interestingly, are, spurious, while, without, in, pcm, to,
# Nearest to not: to, that, but, is, it, be, this, have,
# Nearest to many: notably, and, most, including, more, are, in, among,
# Nearest to or: is, a, are, the, to, of, with, in,
# Nearest to recorded: compilation, records, besieges, cimmerian, boneshaker, crooner, verdeans, wereman,
# Nearest to grand: prix, moulin, centripetal, competences, destabilization, admiring, northeastern, knights,
# Nearest to hold: subtext, heaven, cosets, showdown, chains, barnard, halberd, sld,
# Nearest to prince: oxley, granddaughter, rainier, sirmium, soga, miko, sadr, sensing,
# Nearest to hit: hitters, prominence, ams, fielding, break, track, isostatic, misskelley,
# Nearest to applied: brower, opto, facilitator, cruithne, trinity, fpgas, extinguish, superiority,
# Nearest to operations: homology, bead, abacus, operation, gcd, resents, normalization, peacekeeping,
# Nearest to consists: bicameral, resides, bundesland, ordinaries, comprising, representatives, vpns, newborns,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7479 0.0324 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8332 0.0312 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8364 0.0320 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8257 0.0297 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8199 0.0302 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8876 0.0268 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8520 0.0264 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8017 0.0269 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8405 0.0269 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8436 0.0268 sec/batch
# Nearest to all: are, non, own, every, as, there, a, seven,
# Nearest to however: for, by, soared, was, vg, after, non, rather,
# Nearest to he: his, himself, was, later, career, got, housewife, school,
# Nearest to system: systems, communicative, combatted, nls, albumin, sinaltrainal, majoritarian, nagaoka,
# Nearest to some: interestingly, are, been, in, spurious, pcm, without, while,
# Nearest to not: to, but, that, is, this, it, be, a,
# Nearest to many: most, and, notably, more, including, among, in, are,
# Nearest to or: is, a, are, the, of, to, and, an,
# Nearest to recorded: compilation, records, besieges, cimmerian, jeu, crooner, boneshaker, merengue,
# Nearest to grand: prix, centripetal, moulin, competences, knights, destabilization, northeastern, easterners,
# Nearest to hold: subtext, heaven, chains, showdown, cosets, halberd, redfield, primer,
# Nearest to prince: granddaughter, soga, miko, oxley, bidatsu, rainier, sirmium, hashihito,
# Nearest to hit: hitters, prominence, ams, track, break, isostatic, leavitt, archetypes,
# Nearest to applied: facilitator, opto, brower, fpgas, trinity, cruithne, extinguish, prenatal,
# Nearest to operations: homology, bead, abacus, gcd, resents, operation, peacekeeping, normalization,
# Nearest to consists: bicameral, resides, bundesland, ordinaries, newborns, chooses, altos, tempore,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8490 0.0315 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8213 0.0326 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7966 0.0319 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8267 0.0280 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8771 0.0299 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8304 0.0265 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8356 0.0279 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8533 0.0273 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8022 0.0272 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8060 0.0266 sec/batch
# Nearest to all: are, as, own, every, non, there, a, have,
# Nearest to however: for, was, the, by, soared, after, and, modernization,
# Nearest to he: his, himself, career, later, got, housewife, was, studied,
# Nearest to system: systems, communicative, combatted, majoritarian, albumin, sinaltrainal, nagaoka, its,
# Nearest to some: interestingly, are, in, not, been, while, without, specifically,
# Nearest to not: to, that, is, but, in, this, a, it,
# Nearest to many: and, most, notably, including, more, are, as, among,
# Nearest to or: is, a, are, the, of, to, with, in,
# Nearest to recorded: compilation, records, cimmerian, besieges, verdeans, found, gruyter, wereman,
# Nearest to grand: prix, centripetal, moulin, competences, destabilization, knights, admiring, absence,
# Nearest to hold: subtext, heaven, cosets, chains, showdown, primer, halberd, midwestern,
# Nearest to prince: granddaughter, soga, oxley, miko, sirmium, rainier, bidatsu, slew,
# Nearest to hit: hitters, prominence, ams, track, isostatic, break, penderecki, cowards,
# Nearest to applied: facilitator, opto, brower, trinity, extinguish, cruithne, fpgas, prenatal,
# Nearest to operations: homology, bead, abacus, carmen, gcd, normalization, resents, fencepost,
# Nearest to consists: bicameral, bundesland, resides, ordinaries, head, altos, representatives, comprising,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8626 0.0290 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8102 0.0279 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9406 0.0303 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8991 0.0300 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8878 0.0290 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8398 0.0290 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7539 0.0277 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8537 0.0269 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7325 0.0284 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8834 0.0309 sec/batch
# Nearest to all: are, own, non, there, every, as, have, so,
# Nearest to however: was, by, for, soared, the, after, modernization, decade,
# Nearest to he: his, himself, was, got, career, later, studied, before,
# Nearest to system: systems, combatted, communicative, sinaltrainal, albumin, nls, majoritarian, nagaoka,
# Nearest to some: interestingly, been, not, are, in, while, varied, specifically,
# Nearest to not: to, that, is, but, it, this, a, in,
# Nearest to many: notably, most, and, including, among, more, number, example,
# Nearest to or: is, a, are, the, of, with, in, to,
# Nearest to recorded: compilation, records, besieges, cimmerian, boneshaker, recording, wereman, verdeans,
# Nearest to grand: prix, centripetal, moulin, competences, destabilization, knights, admiring, easterners,
# Nearest to hold: subtext, cosets, heaven, chains, primer, showdown, midwestern, eps,
# Nearest to prince: oxley, miko, soga, rainier, granddaughter, sirmium, sadr, essaioi,
# Nearest to hit: hitters, prominence, ams, track, break, penderecki, isostatic, misskelley,
# Nearest to applied: facilitator, brower, opto, fpgas, trinity, extinguish, prenatal, conduct,
# Nearest to operations: homology, bead, branches, abacus, resents, carmen, peacekeeping, gcd,
# Nearest to consists: bicameral, bundesland, resides, ordinaries, altos, tempore, newborns, sevens,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8417 0.0307 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8452 0.0284 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
